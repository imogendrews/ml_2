# %%
import os
from PIL import Image
import torch
import pandas as pd
from IPython.core.display import display, HTML
from transformers import Blip2Processor, Blip2ForConditionalGeneration


device = "cuda" if torch.cuda.is_available() else "cpu"


processor = Blip2Processor.from_pretrained("Salesforce/blip2-opt-2.7b")
model = Blip2ForConditionalGeneration.from_pretrained(
    "Salesforce/blip2-opt-2.7b", load_in_8bit=True, device_map={"": 0}, torch_dtype=torch.float16
)


image_folder = "university_student"  


image_files = [f for f in os.listdir(image_folder) if f.lower().endswith((".jpg", ".jpeg", ".png"))]


results = []


for image_file in image_files:
    image_path = os.path.join(image_folder, image_file)
    image = Image.open(image_path)

   
    inputs = processor(images=image, return_tensors="pt").to(device, torch.float16)
    generated_ids = model.generate(**inputs)
    caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()

   
    img_tag = f'<img src="{image_path}" width="100"/>'
    results.append({"Image": img_tag, "Image Name": image_file, "Caption": caption})


df = pd.DataFrame(results)


html = df.to_html(escape=False)
display(HTML(html))
# Out:
# C:\Users\ctech\AppData\Local\Temp\ipykernel_20936\3388577334.py:5: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
#   from IPython.core.display import display, HTML
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards: 100%|███████████████████████████| 2/2 [00:08<00:00,  4.00s/it]
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Image</th>
#       <th>Image Name</th>
#       <th>Caption</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="university_student\15_uni.png" width="100"/></td>
#       <td>15_uni.png</td>
#       <td>a young man with a backpack smiles for the camera</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td><img src="university_student\100.png" width="100"/></td>
#       <td>100.png</td>
#       <td>a young woman with a backpack smiles for the camera</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td><img src="university_student\16_uni.png" width="100"/></td>
#       <td>16_uni.png</td>
#       <td>a man with glasses and a backpack</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td><img src="university_student\12.png" width="100"/></td>
#       <td>12.png</td>
#       <td>a man wearing a black jacket</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td><img src="university_student\13_uni.png" width="100"/></td>
#       <td>13_uni.png</td>
#       <td>a young man in a black hoodie and white shirt</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td><img src="university_student\14_uni.png" width="100"/></td>
#       <td>14_uni.png</td>
#       <td>a woman with a backpack</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td><img src="university_student\92.png" width="100"/></td>
#       <td>92.png</td>
#       <td>a man wearing glasses and a maroon hoodie</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td><img src="university_student\93.png" width="100"/></td>
#       <td>93.png</td>
#       <td>a man holding a book</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td><img src="university_student\94.png" width="100"/></td>
#       <td>94.png</td>
#       <td>a man with a backpack</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td><img src="university_student\95.png" width="100"/></td>
#       <td>95.png</td>
#       <td>a young man in a graduation cap and gown holding a book</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td><img src="university_student\96.png" width="100"/></td>
#       <td>96.png</td>
#       <td>a young man with glasses and a white shirt</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td><img src="university_student\97.png" width="100"/></td>
#       <td>97.png</td>
#       <td>a young man in glasses is sitting at a table with a book and a tablet</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td><img src="university_student\98.png" width="100"/></td>
#       <td>98.png</td>
#       <td>a young man sitting at a table with books</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td><img src="university_student\99.png" width="100"/></td>
#       <td>99.png</td>
#       <td>a young man with a backpack and a book</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td><img src="university_student\17_uni.png" width="100"/></td>
#       <td>17_uni.png</td>
#       <td>a man with glasses and a backpack</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td><img src="university_student\18_uni.png" width="100"/></td>
#       <td>18_uni.png</td>
#       <td>a man with a backpack</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td><img src="university_student\19_uni.png" width="100"/></td>
#       <td>19_uni.png</td>
#       <td>a young man with glasses and a backpack</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td><img src="university_student\20_uni.png" width="100"/></td>
#       <td>20_uni.png</td>
#       <td>a young man with a backpack standing in a crowd</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td><img src="university_student\21_uni.png" width="100"/></td>
#       <td>21_uni.png</td>
#       <td>a man with a backpack</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td><img src="university_student\22_uni.png" width="100"/></td>
#       <td>22_uni.png</td>
#       <td>man wearing a gray shirt</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td><img src="university_student\23_uni.png" width="100"/></td>
#       <td>23_uni.png</td>
#       <td>a man with a book and a hat</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td><img src="university_student\24-Uni.png" width="100"/></td>
#       <td>24-Uni.png</td>
#       <td>a young man with glasses and a backpack</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td><img src="university_student\ComfyUI_00001_.png" width="100"/></td>
#       <td>ComfyUI_00001_.png</td>
#       <td>a man wearing glasses</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td><img src="university_student\ComfyUI_00001_2.png" width="100"/></td>
#       <td>ComfyUI_00001_2.png</td>
#       <td>a young man in a green hoodie is sitting at a desk with an open book</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td><img src="university_student\ComfyUI_00001_a.png" width="100"/></td>
#       <td>ComfyUI_00001_a.png</td>
#       <td>a man sitting at a table in a library</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td><img src="university_student\ComfyUI_00001_b.png" width="100"/></td>
#       <td>ComfyUI_00001_b.png</td>
#       <td>a man wearing a gray sweater</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td><img src="university_student\ComfyUI_00001_d.png" width="100"/></td>
#       <td>ComfyUI_00001_d.png</td>
#       <td>a man in a sweater</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td><img src="university_student\ComfyUI_00001_e.png" width="100"/></td>
#       <td>ComfyUI_00001_e.png</td>
#       <td>a young man is standing in front of a building</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td><img src="university_student\ComfyUI_00001_f.png" width="100"/></td>
#       <td>ComfyUI_00001_f.png</td>
#       <td>a young man in a blue hoodie smiling</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td><img src="university_student\ComfyUI_00001_g.png" width="100"/></td>
#       <td>ComfyUI_00001_g.png</td>
#       <td>a young man with a backpack and a smile</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td><img src="university_student\ComfyUI_00002_.png" width="100"/></td>
#       <td>ComfyUI_00002_.png</td>
#       <td>a boy sitting at a table with a book and an open book</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td><img src="university_student\ComfyUI_00002_2.png" width="100"/></td>
#       <td>ComfyUI_00002_2.png</td>
#       <td>a man wearing a white hoodie</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td><img src="university_student\ComfyUI_00002_a.png" width="100"/></td>
#       <td>ComfyUI_00002_a.png</td>
#       <td>a man holding a backpack</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td><img src="university_student\ComfyUI_00002_b.png" width="100"/></td>
#       <td>ComfyUI_00002_b.png</td>
#       <td>a young man wearing glasses and a blue hoodie</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td><img src="university_student\ComfyUI_00002_d.png" width="100"/></td>
#       <td>ComfyUI_00002_d.png</td>
#       <td>a man wearing a pink sweater</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td><img src="university_student\ComfyUI_00002_e.png" width="100"/></td>
#       <td>ComfyUI_00002_e.png</td>
#       <td>a man sitting on a bench</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td><img src="university_student\ComfyUI_00002_f.png" width="100"/></td>
#       <td>ComfyUI_00002_f.png</td>
#       <td>a young man with a backpack smiles for the camera</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td><img src="university_student\ComfyUI_00002_g.png" width="100"/></td>
#       <td>ComfyUI_00002_g.png</td>
#       <td>a young man with a backpack smiling in front of a crowd</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td><img src="university_student\ComfyUI_00003_.png" width="100"/></td>
#       <td>ComfyUI_00003_.png</td>
#       <td>a young man with a backpack smiles for the camera</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td><img src="university_student\ComfyUI_00003_2.png" width="100"/></td>
#       <td>ComfyUI_00003_2.png</td>
#       <td>a young man with a backpack</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td><img src="university_student\ComfyUI_00003_a.png" width="100"/></td>
#       <td>ComfyUI_0000
